# %%
# pip install ipympl, or use %matplotlib inline 
# %matplotlib ipympl
import logging
import tradingbot as tb


class SMACross(tb.Strategy):
    param = {"ticker": "USDT/BTC", "fast": 10, "slow": 20}  # default strategy param

    def start(self):  # function to be called at the startup
        self.logger = logging.getLogger(__name__)
        self.logger.info(f"{self.__class__.__name__} started with param: {self.param}")

    @tb.schedule([tb.trigger.StrategyFirstRun(), tb.trigger.StandardInterval("1h")])  # when to trigger the function
    def next(self, context: dict) -> tb.Order | list[tb.Order] | None:  # function to be called when triggered
        """
        Args:
            context (dict):
                "now": pd.Timestamp, current time
                "trigger": list[Trigger], reason of this run
                "open_order": list[Order], any open orders
        """
        close = self.data["candlestick_1h"]["close"]  # get access to subscribed data from self.data['key']['field']
        ticker, pfast, pslow = self.param["ticker"], self.param["fast"], self.param["slow"]  # get access to parameters from self.param

        # use your favorable way to compute indicators from a pd.Series
        self.sma_fast = close.rolling(window=pfast).mean()  
        self.sma_slow = close.rolling(window=pslow).mean()
        crossup = self.sma_fast.iloc[-2] < self.sma_slow.iloc[-2] and self.sma_fast.iloc[-1] >= self.sma_slow.iloc[-1]
        crossdown = self.sma_fast.iloc[-2] > self.sma_slow.iloc[-2] and self.sma_fast.iloc[-1] <= self.sma_slow.iloc[-1]
        curr_prc = close.iloc[-1]

        if crossup:
            self.logger.info(f"SMA crossed up, buy at {curr_prc:.2f} 🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢")
            order = tb.Order(action="BUY", ticker=ticker, size_type="PCTG", size=1.0, type="MARKET")  # create an all-in market order
        elif crossdown:
            self.logger.info(f"SMA crossed down, sell at {curr_prc:.2f} 🔴🔴🔴🔴🔴🔴🔴🔴🔴🔴🔴🔴")
            order = tb.Order(action="SELL", ticker=ticker, size_type="PCTG", size=1.0, type="MARKET")
        else:
            order = None

        return order

    def stop(self):  # function to be called in the end
        self.logger.info(f"{self.__class__.__name__} stopped")


# fmt: off
bot = tb.Bot( # init a bot
    mode="backtest",  # or "live"
    start="2024-09-01", end="2024-10-01",  # for backtest mode only
)
bot.data = { # subscribe to data 
    # subscribe to USDT/BTC 1h OHLCV from binance
    "candlestick_1h": tb.data.Candlestick("binance", ticker="USDT/BTC", freq="1h", load_len=35)
}
bot.strategy = SMACross(ticker="USDT/BTC", fast=10, slow=30)  # define strategy with param
bot.exchange = tb.exchange.FakeSpotExchange(commission=0.001)  # plug in exchange
bot.account = {"USDT": 10_000}  # init from cash
bot.run(plot=True)  # run the bot
# Out:
# 2024-10-05 12:57:50 [INFO] __main__ <2901334016.py:12>: SMACross started with param: {'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 00:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StrategyFirstRun(), StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 01:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 02:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 03:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 04:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 05:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 06:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 07:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 08:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 09:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 10:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 11:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 12:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 13:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 14:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 15:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 16:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 17:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 18:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 19:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 20:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 21:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 22:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-01 23:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 00:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 01:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 02:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 03:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 04:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 05:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 06:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 07:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 08:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 09:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-02 10:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:50 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09
00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] __main__ <2901334016.py:34>: SMA crossed up, buy at 54869.95 🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 01:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 02:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 03:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 04:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 05:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 06:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 07:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 08:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 09:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 10:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 11:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 12:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 13:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 14:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 15:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 16:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 17:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 18:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 19:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 20:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 21:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 22:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-09 23:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 00:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 01:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 02:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 03:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 04:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 05:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 06:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 07:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 08:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 09:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 10:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 11:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 12:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 13:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 14:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 15:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 16:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 17:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 18:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 19:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 20:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 21:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 22:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-10 23:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-11 00:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-11 01:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-11 02:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:51 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-11 03:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# ...
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 00:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 01:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 02:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 03:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 04:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 05:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 06:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 07:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 08:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 09:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 10:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 11:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 12:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 13:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] __main__ <2901334016.py:37>: SMA crossed down, sell at 65548.12 🔴🔴🔴🔴🔴🔴🔴🔴🔴🔴🔴🔴
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 14:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 15:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 16:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 17:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 18:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 19:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 20:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 21:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 22:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-28 23:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 00:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 01:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 02:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 03:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 04:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 05:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 06:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 07:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 08:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 09:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 10:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 11:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 12:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 13:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 14:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 15:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 16:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 17:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 18:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] __main__ <2901334016.py:34>: SMA crossed up, buy at 65818.01 🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 19:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 20:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 21:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 22:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-29 23:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 00:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 01:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 02:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 03:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 04:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 05:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 06:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:54 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 07:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 08:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 09:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 10:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 11:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 12:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 13:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 14:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 15:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 16:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 17:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 18:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 19:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 20:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 21:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 22:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-09-30 23:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# 2024-10-05 12:57:55 [INFO] tradingbot.bot <bot.py:242>: Now Triggered ⌚'2024-10-01 00:00:00': SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30}) by [StandardInterval('0 days 01:00:00')]
# Strategy                   SMACross({'ticker': 'USDT/BTC', 'fast': 10, 'slow': 30})
# Period                                    2024-09-01 00:00:00 - 2024-10-01 00:00:00
# Exposure Time                                             55.06% x 30 days 00:00:00
# Return Ann vs Benchmark                                           -9.94% vs 265.42%
# Vol Ann vs Benchmark                                               29.94% vs 43.02%
# Max Drawdown                                               8.17% (27 days 21:00:00)
# Sharpe                                                                        -0.20
# Sortino                                                                       -0.24
# Calmar                                                                        -0.73
# IR                                                                            -4.63
# Trade #                                                                          16
# Win Rate                                                                     43.75%
# Avg Win vs Lost Pct                                                 1.38% vs -0.97%
# Avg Trade Duration                                                  1 days 00:48:45
# Profit Factor                                                                  1.08
# Expectancy                                                                    0.06%
# SQN                                                                            0.16
# dtype: object
# 2024-10-05 12:57:55 [INFO] __main__ <2901334016.py:45>: SMACross stopped
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
